# %%
import matplotlib.pyplot as plt
import random

data_list = []
for i in range(10):
    items = []
    for j in range(12):
        items.append(random.randint(15430, 18700))
    data_list.append(items)

plt.boxplot(data_list)
plt.show()
