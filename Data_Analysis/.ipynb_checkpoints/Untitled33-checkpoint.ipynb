# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np

font_path = r'C:\Windows\Fonts\HANDotum.ttf'
font = font_manager.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)

df = pd.read_csv('D:\Data_Analysis\인구현황.csv', encoding='cp949', header=1, index_col=0)
del df['2022년03월_계_총인구수'], df['2022년03월_계_연령구간인구수']
columns = []
for i in range(101):
    columns.append(str(i)+'세')
data = df.iloc[:, :101]
data.columns = columns

name = input('원하는 지역을 입력하세요')
#name = '수곡1동'
result = data.index.str.contains(name)
re_data = data[result]
df2 = re_data

plt.figure(figsize=(30,10))
plt.plot(data.loc[np.power(data.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[0:1]].T, label=data.loc[np.power(data.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[0:1]].T.iloc[0])
plt.plot(data.loc[np.power(data.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[1:2]].T, label=data.loc[np.power(data.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[1:2]].T.iloc[0])
plt.plot(data.loc[np.power(data.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[2:3]].T, label=data.loc[np.power(data.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[2:3]].T.iloc[0])
plt.plot(data.loc[np.power(data.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[3:4]].T, label=data.loc[np.power(data.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[3:4]].T.iloc[0])
plt.plot(data.loc[np.power(data.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[4:5]].T, label=data.loc[np.power(data.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[4:5]].T.iloc[0])
plt.xticks(rotation=90)
plt.xlim([0,100])
plt.legend()
plt.show()
# Out:
# 원하는 지역을 입력하세요경상남도 양산시 물금읍
