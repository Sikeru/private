# %%
import csv
from selenium import webdriver
import time

driver = webdriver.Chrome(executable_path='./chromedriver')
url = 'https://machinelearningforkids.co.uk/'
driver.get(url)
time.sleep(1)
driver.find_element_by_xpath('/html/body/div/div/div/div/div[1]/div/button[1]').click()
time.sleep(1)
driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div[3]/button').click()
time.sleep(1)
driver.find_element_by_xpath('//*[@id="auth0-lock-container-1"]/div/div[2]/form/div/div/div/div/div[2]/div[2]/span/div/div/div/div/div/div/div/div/div/div/div[1]/div/input').send_keys("wltn5582")
time.sleep(1)
driver.find_element_by_xpath('//*[@id="1-password"]').send_keys("qkr02071230")
time.sleep(1)
driver.find_element_by_xpath('//*[@id="1-submit"]').click()
time.sleep(6)
driver.find_element_by_xpath('/html/body/div/div/div/div/div[1]/div/button[2]').click()
time.sleep(3)
driver.find_element_by_xpath('//*[@id="8f66ace0-b745-11ec-8e5f-3f36119ee050"]/div[1]').click()
time.sleep(3)
driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[1]/div[3]/button').click()
time.sleep(4)

f=open('한번더실험.csv', 'r', encoding='cp949')
data=csv.reader(f)
next(data)
header = next(data)

for j in range(426):
    next(data)

for row in data:
#     print(row[0], row[1], row[2], row[3], row[4], row[5])
    driver.find_element_by_xpath('/html/body/div/div/div/div[3]/div[2]/div/div[3]/div').click()
    time.sleep(3)
    
    for i in range(1, 7):
        driver.find_element_by_name(str(i)).send_keys(row[i-1])
        time.sleep(0.5)
    
    time.sleep(1)    
    driver.find_element_by_xpath('/html/body/div/div[3]/md-dialog/form[2]/md-dialog-actions/button[1]').click()
    time.sleep(1)
# Out:
# <ipython-input-10-950f2c59d482>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='./chromedriver')
# <ipython-input-10-950f2c59d482>:9: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div/div/div/div/div[1]/div/button[1]').click()
# <ipython-input-10-950f2c59d482>:11: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div[3]/button').click()
# <ipython-input-10-950f2c59d482>:13: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
# ...

# %%
import csv
from selenium import webdriver
import time

driver = webdriver.Chrome(executable_path='./chromedriver')
url = 'https://machinelearningforkids.co.uk/'
driver.get(url)
time.sleep(1)
driver.find_element_by_xpath('/html/body/div/div/div/div/div[1]/div/button[1]').click()
time.sleep(1)
driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div[3]/button').click()
time.sleep(1)
driver.find_element_by_xpath('//*[@id="auth0-lock-container-1"]/div/div[2]/form/div/div/div/div/div[2]/div[2]/span/div/div/div/div/div/div/div/div/div/div/div[1]/div/input').send_keys("wltn5582")
time.sleep(1)
driver.find_element_by_xpath('//*[@id="1-password"]').send_keys("qkr02071230")
time.sleep(1)
driver.find_element_by_xpath('//*[@id="1-submit"]').click()
time.sleep(6)
driver.find_element_by_xpath('/html/body/div/div/div/div/div[1]/div/button[2]').click()
time.sleep(3)
driver.find_element_by_xpath('//*[@id="8f66ace0-b745-11ec-8e5f-3f36119ee050"]/div[1]').click()
time.sleep(3)
driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[1]/div[3]/button').click()
time.sleep(4)

f=open('한번더실험.csv', 'r', encoding='cp949')
data=csv.reader(f)
next(data)
header = next(data)

for j in range(1,45):
    driver.find_element_by_xpath('/html/body/div/div/div/div[3]/div[2]/div[2]/div[3]/div').click()
    time.sleep(3)
    
    for i in range(1, 7):
        driver.find_element_by_name(str(i)).send_keys(str(j))
        time.sleep(0.5)
    
    time.sleep(1)    
    driver.find_element_by_xpath('/html/body/div/div[3]/md-dialog/form[2]/md-dialog-actions/button[1]').click()
    time.sleep(1)
# Out:
# <ipython-input-14-b4ced2abe0c1>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='./chromedriver')
# <ipython-input-14-b4ced2abe0c1>:9: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div/div/div/div/div[1]/div/button[1]').click()
# <ipython-input-14-b4ced2abe0c1>:11: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('/html/body/div/div/div[2]/div/div[3]/button').click()
# <ipython-input-14-b4ced2abe0c1>:13: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
# ...

# %%
import csv

f=open('한번더실험.csv', 'r', encoding='cp949')
data=csv.reader(f)
next(data)
header = next(data)
for j in range(426):
    next(data)

for row in data:
    print(row)
# Out:
# ['7', '18', '30', '39', '40', '41', '36']
# ['8', '17', '27', '33', '40', '44', '24']
# ['2', '12', '14', '33', '40', '41', '25']
# ['3', '5', '14', '20', '42', '44', '33']
# ['5', '7', '9', '11', '32', '35', '33']
# ['5', '7', '20', '22', '37', '42', '39']
# ['5', '12', '14', '32', '34', '42', '16']
# ['16', '17', '22', '31', '34', '37', '33']
# ['10', '11', '15', '25', '35', '41', '13']
# ['2', '8', '20', '30', '33', '34', '6']
# ['14', '15', '16', '19', '25', '43', '2']
# ['2', '4', '20', '34', '35', '43', '14']
# ['3', '13', '18', '33', '37', '45', '1']
# ['11', '18', '21', '26', '38', '43', '29']
# ['1', '12', '26', '27', '29', '33', '42']
# ['3', '6', '13', '23', '24', '35', '1']
# ['1', '3', '17', '20', '31', '44', '40']
# ['1', '10', '15', '16', '32', '41', '28']
# ['4', '5', '6', '25', '26', '43', '41']
# ['4', '10', '18', '27', '40', '45', '38']
# ['14', '19', '25', '26', '27', '34', '2']
# ['5', '10', '16', '17', '31', '32', '21']
# ...
