# %%
import matplotlib.pyplot as plt

kor = [80,90,88,79,95,67,69,70,85,99]
eng = [67,78,69,80,70,60,70,80,60,90]

plt.scatter(kor, eng, c=range(10))
plt.plot(range(max(kor)),range(max(kor)))
plt.colorbar()
plt.show()
