# %%
#9세 이상 24세 이하인 청소년 인구가 많은 순으로 10개 지역을 찾아보고 막대그래프로 작성하시오 
import csv
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np

font_path = r'C:\Windows\Fonts\HANDotum.ttf'
font = font_manager.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)

f=open('D:\Data_Analysis\인구현황.csv', 'r', encoding='cp949')
data = csv.reader(f)
next(data)
header = next(data)
data=list(data)

age={}
for row in data:
    row[3:] = map(int, row[3:])
    if row[0].count('0', 0, len(row[0])) < 5:
        if row[0] not in age:
            age[row[0]]=np.sum(row[3:10])

sorted_dict = sorted(age.items(), key = lambda item: item[1], reverse=99999999)
cnt=0
addr =[]
poputl = []

for row in sorted_dict:
    print(row)
#    addr.append()
# Out:
# ('경상남도 양산시 물금읍(4833025300)', 9684)
# ('경기도 화성시 동탄7동(4159061000)', 9064)
# ('경기도 남양주시 다산1동(4136054500)', 7937)
# ('경기도 광주시 오포읍(4161025000)', 6932)
# ('부산광역시 강서구 명지1동(2644053500)', 6723)
# ('부산광역시 기장군 정관읍(2671025600)', 6532)
# ('충청남도 천안시 서북구 부성2동(4413359000)', 6365)
# ('경기도 화성시 향남읍(4159025900)', 6302)
# ('충청북도 청주시 청원구 오창읍(4311425300)', 6281)
# ('충청남도 아산시 배방읍(4420025300)', 6111)
# ('경상남도 김해시 장유3동(4825063000)', 6104)
# ('경기도 부천시 신중동(4119074200)', 6039)
# ('경기도 파주시 운정3동(4148057000)', 6025)
# ('경기도 부천시 범안동(4119079500)', 5401)
# ('경기도 파주시 운정2동(4148056000)', 5252)
# ('경기도 남양주시 별내동(4136057000)', 5236)
# ('광주광역시 광산구 수완동(2920063700)', 5056)
# ('전라북도 전주시 덕진구 송천1동(4511364100)', 4958)
# ('경기도 양주시 회천4동(4163056000)', 4932)
# ('경기도 화성시 봉담읍(4159025300)', 4900)
# ('경기도 시흥시 은행동(4139054000)', 4814)
# ('서울특별시 송파구 위례동(1171064700)', 4803)
# ('경기도 화성시 동탄4동(4159058800)', 4671)
# ('경기도 부천시 상동(4119074400)', 4584)
# ('경상북도 포항시 북구 장량동(4711370000)', 4553)
# ('경기도 김포시 운양동(4157058000)', 4517)
# ...

# %%
age={}
for row in data:
    row[3:] = map(int, row[3:])
    if row[0].count('0', 0, len(row[0])) < 5:
        if row[0] not in age:
            age[row[0]]=np.sum(row[28:37])

sorted_dict = sorted(age.items(), key = lambda item: item[1], reverse=99999999)
cnt=0
addr =[]
popul = []

for row in sorted_dict:
    print(row)
    addr.append(row[0][ : row[0].find('(')])
    popul.append(row[1])
    if cnt>=0: 
        pass
# Out:
# ('경기도 부천시 신중동(4119074200)', 18864)
# ('경상남도 양산시 물금읍(4833025300)', 14081)
# ('경기도 광주시 오포읍(4161025000)', 13985)
# ('경기도 부천시 부천동(4119060600)', 11641)
# ('서울특별시 관악구 청룡동(1162059500)', 11463)
# ('경기도 화성시 향남읍(4159025900)', 11434)
# ('경기도 하남시 미사1동(4145061000)', 11376)
# ('충청남도 아산시 배방읍(4420025300)', 11322)
# ('경기도 부천시 오정동(4119083000)', 11222)
# ('충청북도 청주시 청원구 오창읍(4311425300)', 11083)
# ('경기도 부천시 대산동(4119074600)', 10972)
# ('경기도 화성시 동탄7동(4159061000)', 10933)
# ('경기도 부천시 상동(4119074400)', 10290)
# ('충청남도 천안시 서북구 부성2동(4413359000)', 10154)
# ('경기도 남양주시 다산1동(4136054500)', 10119)
# ('경기도 부천시 범안동(4119079500)', 10072)
# ('서울특별시 강남구 역삼1동(1168064000)', 9991)
# ('경기도 남양주시 별내동(4136057000)', 9959)
# ('충청남도 천안시 서북구 부성1동(4413358000)', 9882)
# ('서울특별시 금천구 독산제1동(1154561000)', 9877)
# ('경기도 부천시 심곡동(4119060300)', 9776)
# ('경기도 파주시 운정3동(4148057000)', 9740)
# ('경상남도 김해시 내외동(4825054000)', 9729)
# ('서울특별시 영등포구 영등포동(1156053500)', 9713)
# ('경기도 화성시 봉담읍(4159025300)', 9694)
# ('서울특별시 관악구 신림동(1162069500)', 9511)
# ...
